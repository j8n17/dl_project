# %%
from data_loader.data_loaders import CustomDataLoader, CustomDataset
import matplotlib.pyplot as plt
import numpy as np
from torchvision import datasets, transforms

dataloader = CustomDataLoader("./data", 'train.txt', 8, True, 2, 'train', 'rgb_diff')

data, label = next(iter(dataloader))

# %%
def show_images(images):
    # 이미지의 개수만큼 subplot 생성
    fig, axes = plt.subplots(1, 7, figsize=(20, 20))
    
    for i, ax in enumerate(axes):
        # numpy 배열을 이미지 형식으로 변환 (3, 224, 224) -> (224, 224, 3)
        img = images[i].transpose(1, 2, 0)
        ax.imshow(img)
        ax.axis('off')  # 축 레이블 제거
    plt.show()

# %%
# 이미지 표시
show_images(data.numpy()[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 이미지 표시
show_images(data.numpy()[0])
